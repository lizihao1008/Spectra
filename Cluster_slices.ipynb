# %% [markdown]
# Select the part of the field (between the two black lines) where there is a big cluster.

# %%
for i in range(50,60,2):
    fig = figure(figsize=(20,3))
    ax = fig.add_subplot(111)
    ax.imshow(cla_contrast_wiener[i],cmap='jet_r',origin='lower',vmin=-0.55,vmax=0.4)
    ax.axvline(730,color='k')
    ax.axvline(690,color='k')
    ax.xaxis.set_major_formatter(plt.FuncFormatter(format_funcx))
    ax.yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))

    show()

# %%
for i in range(50,60,2):
    fig = figure(figsize=(20,3))
    ax = fig.add_subplot(111)
    ax.imshow(cla_contrast_orca[i],cmap='jet_r',origin='lower',vmin=-0.55,vmax=0.4)
    ax.axvline(730,color='k')
    ax.axvline(690,color='k')
    ax.xaxis.set_major_formatter(plt.FuncFormatter(format_funcx))
    ax.yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    show()

# %% [markdown]
# WF slices moving in direction of LOS

# %%
def format_funcx(value,ticks):
    return int((value+690)/2+3657)
def format_funcy(value,ticks):
    return int(value/2)
fig,ax = subplots(2,14,figsize=(20,5),sharey='row')
subplots_adjust(wspace=0.1)
ii = 0
a = 16
for i in range(690,730,3):
    ax[0,ii].imshow(cla_contrast_wiener[55][:,690:730],origin='lower',cmap='jet_r',vmin=-0.55,vmax=0.4)
    ax[0,ii].axvline(i-690,c='k')
#     ax[0,ii].set_xlim(0,40)
    ax[0,ii].set_ylim(0,48)
    ax[1,ii].imshow(cla_contrast_wiener[...,i],cmap='jet_r',vmin=-0.55,vmax=0.4)
    ax[1,ii].axis('equal')
    
    ax[0,ii].xaxis.set_major_formatter(plt.FuncFormatter(format_funcx))
    ax[0,ii].yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    ax[1,ii].xaxis.set_major_formatter(plt.FuncFormatter(format_funcx))
    ax[1,ii].yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    
    ax[0,6].set_xlabel('LOS(Mpc/h)',fontsize=a)
    ax[1,6].set_xlabel('Dec(Mpc/h)',fontsize=a)
    ax[0,0].set_ylabel('Dec(Mpc/h)',fontsize=a)
    ax[1,0].set_ylabel('RA (Mpc/h)',fontsize=a)

    ii+=1
suptitle('WF',fontsize=a)

show()

# %% [markdown]
# WF slices moving in direction of Dec

# %%
fig,ax = subplots(2,16,figsize=(20,5),sharey='row')
subplots_adjust(wspace=0.1)
ii = 0
a = 16
for i in range(0,48,3):
    ax[0,ii].imshow(cla_contrast_wiener[55][:,690:730],origin='lower',cmap='jet_r',vmin=-0.55,vmax=0.4)
    ax[0,ii].axhline(i,c='k')
    ax[0,ii].set_ylim(0,48)
    ax[1,ii].imshow(cla_contrast_wiener[:,i,][:,690:730],cmap='jet_r',vmin=-0.55,vmax=0.4)
    ax[1,ii].axis('equal')
    
    ax[0,ii].xaxis.set_major_formatter(plt.FuncFormatter(format_funcx))
    ax[0,ii].yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    ax[1,ii].xaxis.set_major_formatter(plt.FuncFormatter(format_funcx))
    ax[1,ii].yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    
    ax[0,7].set_xlabel('LOS (Mpc/h)',fontsize=a)
    ax[1,7].set_xlabel('LOS (Mpc/h)',fontsize=a)
    ax[0,0].set_ylabel('Dec(Mpc/h)',fontsize=a)
    ax[1,0].set_ylabel('RA (Mpc/h)',fontsize=a)

    ii+=1
suptitle('WF',fontsize=a)

show()

# %% [markdown]
# ORCA slices moving in direction of LOS

# %%
fig,ax = subplots(2,14,figsize=(20,5),sharey='row')
subplots_adjust(wspace=0.1)
ii = 0
a = 16
for i in range(690,730,3):
    ax[0,ii].imshow(cla_contrast_orca[55][:,690:730],origin='lower',cmap='jet_r',vmin=-0.55,vmax=0.4)
    ax[0,ii].axvline(i-690,c='k')
#     ax[0,ii].set_xlim(0,40)
    ax[0,ii].set_ylim(0,48)
    ax[1,ii].imshow(cla_contrast_orca[...,i],cmap='jet_r',vmin=-0.55,vmax=0.4)
    ax[1,ii].axis('equal')
    
    ax[0,ii].xaxis.set_major_formatter(plt.FuncFormatter(format_funcx))
    ax[0,ii].yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    ax[1,ii].xaxis.set_major_formatter(plt.FuncFormatter(format_funcx))
    ax[1,ii].yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    
    ax[0,6].set_xlabel('LOS(Mpc/h)',fontsize=a)
    ax[1,6].set_xlabel('Dec(Mpc/h)',fontsize=a)
    ax[0,0].set_ylabel('Dec(Mpc/h)',fontsize=a)
    ax[1,0].set_ylabel('RA (Mpc/h)',fontsize=a)
    ii+=1
suptitle('ORCA',fontsize=a)
show()

# %% [markdown]
# ORCA slices moving in direction of Dec

# %%
fig,ax = subplots(2,16,figsize=(20,5),sharey='row')
subplots_adjust(wspace=0.1)
ii = 0
a = 16
for i in range(0,48,3):
    ax[0,ii].imshow(cla_contrast_orca[55][:,690:730],origin='lower',cmap='jet_r',vmin=-0.55,vmax=0.4)
    ax[0,ii].axhline(i,c='k')
    ax[0,ii].set_ylim(0,48)
    ax[1,ii].imshow(cla_contrast_orca[:,i,][:,690:730],cmap='jet_r',vmin=-0.55,vmax=0.4)
    ax[1,ii].axis('equal')
    
    ax[0,ii].xaxis.set_major_formatter(plt.FuncFormatter(format_funcx))
    ax[0,ii].yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    ax[1,ii].xaxis.set_major_formatter(plt.FuncFormatter(format_funcx))
    ax[1,ii].yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    
    ax[0,7].set_xlabel('LOS (Mpc/h)',fontsize=a)
    ax[1,7].set_xlabel('LOS (Mpc/h)',fontsize=a)
    ax[0,0].set_ylabel('Dec(Mpc/h)',fontsize=a)
    ax[1,0].set_ylabel('RA (Mpc/h)',fontsize=a)

    ii+=1
suptitle('ORCA',fontsize=a)

show()

# %% [markdown]
# Comaprsion of WF and ORCA slices moving in direction of LOS

# %%
fig,ax = subplots(2,14,figsize=(20,5),sharey='row')
subplots_adjust(wspace=0.1)
ii = 0
a = 16
for i in range(690,730,3):
    ax[0,ii].imshow(cla_contrast_wiener[...,i],origin='lower',cmap='jet_r',vmin=-0.55,vmax=0.4)
    ax[1,ii].imshow(cla_contrast_orca[...,i],origin='lower',cmap='jet_r',vmin=-0.55,vmax=0.4)
#     ax[1,ii].axis('equal')
    
    ax[0,ii].xaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    ax[0,ii].yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    ax[1,ii].xaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    ax[1,ii].yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    
    ax[1,6].set_xlabel('Dec(Mpc/h)',fontsize=a)
    ax[0,0].set_ylabel('RA(Mpc/h)',fontsize=a)
    ax[1,0].set_ylabel('RA (Mpc/h)',fontsize=a)
    ax[0,6].set_title('WF')
    ax[1,6].set_title('ORCA')

    ii+=1

show()

# %% [markdown]
# Comaprsion of WF and ORCA slices moving in direction of Dec

# %%
fig,ax = subplots(2,16,figsize=(20,5),sharey='row')
subplots_adjust(wspace=0.1)
ii = 0
a = 16
for i in range(0,48,3):
    ax[0,ii].imshow(cla_contrast_wiener[:,i,][:,690:730],origin='lower',cmap='jet_r',vmin=-0.55,vmax=0.4)
    ax[1,ii].imshow(cla_contrast_orca[:,i,][:,690:730],origin='lower',cmap='jet_r',vmin=-0.55,vmax=0.4)
    
    ax[0,ii].xaxis.set_major_formatter(plt.FuncFormatter(format_funcx))
    ax[0,ii].yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    ax[1,ii].xaxis.set_major_formatter(plt.FuncFormatter(format_funcx))
    ax[1,ii].yaxis.set_major_formatter(plt.FuncFormatter(format_funcy))
    
    ax[1,7].set_xlabel('LOS (Mpc/h)',fontsize=a)
    ax[0,0].set_ylabel('RA(Mpc/h)',fontsize=a)
    ax[1,0].set_ylabel('RA (Mpc/h)',fontsize=a)
    ax[0,7].set_title('WF')
    ax[1,7].set_title('ORCA')

    ii+=1

show()

# %% [markdown]
# ## 3-D visualization using mayavi
# Wire: isosurface at flux constrast=-0.4
#
# Translucent: isosurface at flux constrast=-0.15

# %% [markdown]
# ![avatar](./clamato_3d.png)

# %% [markdown]
# ![avatar](./clamato_3d_2.png)
